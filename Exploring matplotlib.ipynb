# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
np.random.seed(12345)
nums = np.random.normal(10000,100,10000)
#print(nums)
plt.hist(nums, density=True, bins=25)
plt.show()
